# %% [markdown]
# # Interactive Spectra Browser
#
# Download full zipped RELAB database from: [sites.brown.edu/relab/relab-spectral-database/](https://sites.brown.edu/relab/relab-spectral-database/).
#
# At time of writing, it is hosted at the link: [DOWNLOAD CATALOGUES & TEXT DATA FILES](https://drive.google.com/drive/folders/1KNvZSw5nPa75CUG0-FZsaLq29b7B-ZTU?usp=sharing).
#
# Unzip the database and then run the cell below, ensuring `database_path` points to the directory containing the unzipped database.

# %%
from pyspectacle import RelabParser, SpectraBrowser
database_path = '/mnt/c/Users/cjtai/Downloads/RelabDatabase2024Dec31'
parser = RelabParser(database_path)
browser = SpectraBrowser(parser)
browser.display()
